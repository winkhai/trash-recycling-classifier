# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# ### prep data

# %%
from fastai.vision import *
from fastai.metrics import error_rate
from pathlib import Path
from glob2 import glob
from sklearn.metrics import confusion_matrix

import pandas as pd
import numpy as np
import os
import zipfile as zf
import shutil
import re
import seaborn as sns

# %%
## helper functions ##

## splits indices for a folder into train, validation, and test indices with random sampling
    ## input: folder path
    ## output: train, valid, and test indices    
def split_indices(folder,seed1,seed2):    
    n = len(os.listdir(folder))
    full_set = list(range(1,n+1))

    ## train indices
    random.seed(seed1)
    train = random.sample(list(range(1,n+1)),int(.7*n))

    ## temp
    remain = list(set(full_set)-set(train))

    ## separate remaining into validation and test
    random.seed(seed2)
    valid = random.sample(remain,int(.5*len(remain)))
    test = list(set(remain)-set(valid))
    
    return(train,valid,test)

## gets file names for a particular type of trash, given indices
    ## input: waste category and indices
    ## output: file names 
def get_names(waste_type,indices):
    file_names = [waste_type+str(i)+".jpg" for i in indices]
    return(file_names)    

## moves group of source files to another folder
    ## input: list of source files and destination folder
    ## no output
def move_files(source_files,destination_folder):
    for file in source_files:
        shutil.move(file,destination_folder)

# %%
# !ls ../data/
# Out:
# dataset-resized  dataset-resized.zip  __MACOSX	models	test  train  valid

# %%
DATA_PATH = os.path.join('..', 'data')

RAW_DATA_PATH = os.path.join('..', 'data', 'dataset-resized')

## paths will be train/cardboard, train/glass, etc...
subsets = ['train','valid', 'test']
waste_types = ['cardboard','glass','metal','paper','plastic','trash']

## create destination folders for data subset and waste type
for subset in subsets:
    if not os.path.exists(os.path.join(DATA_PATH, subset)):
        os.makedirs(os.path.join(DATA_PATH, subset))
    for waste_type in waste_types:
        folder = os.path.join(DATA_PATH, subset, waste_type)
        #if os.path.exists(folder):
          #print(f'folder {folder} already exists.')
          #return
        if not os.path.exists(folder):
            os.makedirs(folder)
            

            
## move files to destination folders for each waste type
for waste_type in waste_types:
    source_folder = os.path.join(RAW_DATA_PATH,waste_type)
    train_ind, valid_ind, test_ind = split_indices(source_folder,1,1)
    
    ## move source files to train
    train_names = get_names(waste_type,train_ind)
    train_source_files = [os.path.join(source_folder,name) for name in train_names]
    train_dest = os.path.join(DATA_PATH, 'train', waste_type)
    move_files(train_source_files,train_dest)
    
    ## move source files to valid
    valid_names = get_names(waste_type,valid_ind)
    valid_source_files = [os.path.join(source_folder,name) for name in valid_names]
    valid_dest = os.path.join(DATA_PATH, 'valid', waste_type)
    move_files(valid_source_files,valid_dest)
    
    ## move source files to test
    test_names = get_names(waste_type, test_ind)
    test_source_files = [os.path.join(source_folder,name) for name in test_names]
    ## I use data/test here because the images can be mixed up
    test_dest = os.path.join(DATA_PATH, 'test', waste_type)
    move_files(test_source_files, test_dest)

# %%
path = Path(DATA_PATH)

# %%
tfms = get_transforms(do_flip=True, flip_vert=True)
bs = 16
num_workers = 0
data = ImageDataBunch.from_folder(path,
                                  test='test',
                                  ds_tfms=tfms,
                                  bs=bs,
                                  num_workers=num_workers)

# %%
print(data.classes)
# Out:
# ['cardboard', 'glass', 'metal', 'paper', 'plastic', 'trash']

# %%
data.show_batch(rows=2, figsize=(7, 8))

# %%
learn = create_cnn(data, models.resnet18, metrics=[error_rate, accuracy])
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /home/ubuntu/.cache/torch/checkpoints/resnet18-5c106cde.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 196MB/s]

# %%
learn.lr_find(start_lr=1e-6, end_lr=1e1)
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(6, max_lr=.01)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.908557</td>
#       <td>1.338835</td>
#       <td>0.362434</td>
#       <td>0.637566</td>
#       <td>01:14</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.058510</td>
#       <td>0.741124</td>
#       <td>0.248677</td>
#       <td>0.751323</td>
#       <td>01:14</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.857008</td>
#       <td>0.443758</td>
#       <td>0.161376</td>
#       <td>0.838624</td>
#       <td>01:12</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.512875</td>
#       <td>0.338498</td>
#       <td>0.116402</td>
#       <td>0.883598</td>
#       <td>01:10</td>
#     </tr>
#   </tbody>
# </table>

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
losses, idxs = interp.top_losses()

# %%
interp.plot_top_losses(9, figsize=(15, 11))

# %%
interp.most_confused(min_val=2)
# Out:
# [('glass', 'metal', 9),
#  ('glass', 'plastic', 5),
#  ('plastic', 'glass', 5),
#  ('cardboard', 'paper', 4),
#  ('metal', 'glass', 4),
#  ('trash', 'metal', 4),
#  ('trash', 'paper', 4),
#  ('paper', 'trash', 2),
#  ('plastic', 'paper', 2)]

# %%
interp.plot_confusion_matrix(figsize=(6, 6))

# %% [markdown]
# ### 4. Make new predictions on test data

# %%
preds = learn.get_preds(ds_type=DatasetType.Test)

# %%
preds[0]
# Out:
# tensor([[6.9716e-04, 3.6840e-02, 9.3771e-03, 4.5621e-03, 9.3699e-01, 1.1536e-02],
#         [8.4530e-04, 8.7529e-01, 5.9818e-02, 7.0947e-03, 3.6076e-02, 2.0873e-02],
#         [3.3800e-05, 9.5737e-01, 4.0101e-02, 8.2857e-06, 2.4839e-03, 7.9035e-06],
#         ...,
#         [3.5828e-03, 5.8233e-04, 9.9939e-05, 9.6186e-01, 4.4238e-03, 2.9446e-02],
#         [6.8113e-05, 3.8158e-05, 6.2768e-04, 9.9882e-01, 3.8213e-04, 6.2416e-05],
#         [1.4401e-03, 7.0720e-03, 1.3839e-05, 9.8662e-01, 2.5293e-03, 2.3287e-03]])
